# %%
import torch
import numpy as np
import plyfile
import os
import laspy

# %%
num_classes = 5

# 0- nth, 1 - pole, 2 - road line, 3 - road, 4 - traffic sign 
class Paris():
    def __init__(self, path) -> None:
        if not os.path.exists(path):
            return
        
        ply = plyfile.PlyData.read(path)
        print(ply)
        
        x = torch.from_numpy(np.asarray(ply.elements[0]['X']).copy())
        y = torch.from_numpy(np.asarray(ply.elements[0]['Y']).copy())
        z = torch.from_numpy(np.asarray(ply.elements[0]['Z']).copy())
        intensity = torch.from_numpy(np.asarray(ply.elements[0]['Intensity']).copy()) / 255.0
        self.points = torch.stack([x, y, z, intensity], dim=1)
    
        self.frame_index = torch.from_numpy(np.asarray(ply.elements[0]['Frame_Index'], dtype=np.int32).copy()) - 1
        self.num_frames = self.frame_index[-1]
        
        self.gps_time = torch.from_numpy(np.asarray(ply.elements[0]['GPS_Time'], dtype=np.int32).copy())
        
        
    def get_points(self, idx) -> torch.Tensor:
        return self.points[self.frame_index == idx]

# %%
paris = Paris('data/Lille1/Lille_0.ply')
# Out:
# ply
# format binary_little_endian 1.0
# element vertex 10000000
# property double X
# property double Y
# property double Z
# property uchar Intensity
# property float Scan_Angle
# property double GPS_Time
# property double X_Sensor_Position
# property double Y_Sensor_Position
# property double Z_Sensor_Position
# property float Vertical_Laser_Angle
# property uchar Laser_Index
# property uint Frame_Index
# end_header

# %%
paris.frame_index
# Out:
# tensor([  0,   0,   0,  ..., 215, 215, 215], dtype=torch.int32)

# %%
from vision.PointTransformer import PointTransformerSeg

seg_model = PointTransformerSeg(4, num_classes)
seg_model.load_state_dict(torch.load('data/point_transformer_seg.pt'))
seg_model.cuda()
seg_model.eval()
# Out:
# PointTransformerSeg(
#   (mlp1): SingleMLP(
#     (fc): Linear(in_features=4, out_features=32, bias=True)
#     (bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transformer1): PointTransformerBlock(
#     (transformerLayer): PointTransformerLayer(
#       (query): Linear(in_features=32, out_features=32, bias=True)
#       (key): Linear(in_features=32, out_features=32, bias=True)
#       (value): Linear(in_features=32, out_features=32, bias=True)
#       (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#       (fc_delta2): Linear(in_features=3, out_features=32, bias=True)
#       (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc_gamma1): Linear(in_features=32, out_features=32, bias=True)
#       (fc_gamma2): Linear(in_features=32, out_features=32, bias=True)
#       (bn_gamma1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_gamma2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc1): Linear(in_features=32, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=32, bias=True)
#     (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (mlp2): SingleMLP(
#     (fc): Linear(in_features=512, out_features=512, bias=True)
#     (bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (transformer2): PointTransformerBlock(
#     (transformerLayer): PointTransformerLayer(
#       (query): Linear(in_features=512, out_features=512, bias=True)
#       (key): Linear(in_features=512, out_features=512, bias=True)
#       (value): Linear(in_features=512, out_features=512, bias=True)
#       (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#       (fc_delta2): Linear(in_features=3, out_features=512, bias=True)
#       (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (fc_gamma1): Linear(in_features=512, out_features=512, bias=True)
#       (fc_gamma2): Linear(in_features=512, out_features=512, bias=True)
#       (bn_gamma1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_gamma2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc1): Linear(in_features=512, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=512, bias=True)
#     (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (down_blocks): ModuleList(
#     (0): TransitionDownBlock(
#       (transition): TransitionDown(
#         (fc): Linear(in_features=35, out_features=64, bias=True)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=64, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=64, out_features=64, bias=True)
#           (fc_gamma2): Linear(in_features=64, out_features=64, bias=True)
#           (bn_gamma1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=64, out_features=64, bias=True)
#         (fc2): Linear(in_features=64, out_features=64, bias=True)
#         (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): TransitionDownBlock(
#       (transition): TransitionDown(
#         (fc): Linear(in_features=67, out_features=128, bias=True)
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=128, out_features=128, bias=True)
#           (key): Linear(in_features=128, out_features=128, bias=True)
#           (value): Linear(in_features=128, out_features=128, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=128, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=128, out_features=128, bias=True)
#           (fc_gamma2): Linear(in_features=128, out_features=128, bias=True)
#           (bn_gamma1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=128, out_features=128, bias=True)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): TransitionDownBlock(
#       (transition): TransitionDown(
#         (fc): Linear(in_features=131, out_features=256, bias=True)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=256, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=256, out_features=256, bias=True)
#           (fc_gamma2): Linear(in_features=256, out_features=256, bias=True)
#           (bn_gamma1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=256, out_features=256, bias=True)
#         (fc2): Linear(in_features=256, out_features=256, bias=True)
#         (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): TransitionDownBlock(
#       (transition): TransitionDown(
#         (fc): Linear(in_features=259, out_features=512, bias=True)
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=512, out_features=512, bias=True)
#           (key): Linear(in_features=512, out_features=512, bias=True)
#           (value): Linear(in_features=512, out_features=512, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=512, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=512, out_features=512, bias=True)
#           (fc_gamma2): Linear(in_features=512, out_features=512, bias=True)
#           (bn_gamma1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=512, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=512, bias=True)
#         (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (up_blocks): ModuleList(
#     (0): TransitionUpBlock(
#       (transition): TransitionUp(
#         (f1_fc): Linear(in_features=256, out_features=256, bias=True)
#         (f1_bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (f2_fc): Linear(in_features=512, out_features=256, bias=True)
#         (f2_bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=256, out_features=256, bias=True)
#           (key): Linear(in_features=256, out_features=256, bias=True)
#           (value): Linear(in_features=256, out_features=256, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=256, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=256, out_features=256, bias=True)
#           (fc_gamma2): Linear(in_features=256, out_features=256, bias=True)
#           (bn_gamma1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=256, out_features=256, bias=True)
#         (fc2): Linear(in_features=256, out_features=256, bias=True)
#         (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): TransitionUpBlock(
#       (transition): TransitionUp(
#         (f1_fc): Linear(in_features=128, out_features=128, bias=True)
#         (f1_bn): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (f2_fc): Linear(in_features=256, out_features=128, bias=True)
#         (f2_bn): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=128, out_features=128, bias=True)
#           (key): Linear(in_features=128, out_features=128, bias=True)
#           (value): Linear(in_features=128, out_features=128, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=128, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=128, out_features=128, bias=True)
#           (fc_gamma2): Linear(in_features=128, out_features=128, bias=True)
#           (bn_gamma1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=128, out_features=128, bias=True)
#         (fc2): Linear(in_features=128, out_features=128, bias=True)
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): TransitionUpBlock(
#       (transition): TransitionUp(
#         (f1_fc): Linear(in_features=64, out_features=64, bias=True)
#         (f1_bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (f2_fc): Linear(in_features=128, out_features=64, bias=True)
#         (f2_bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=64, out_features=64, bias=True)
#           (key): Linear(in_features=64, out_features=64, bias=True)
#           (value): Linear(in_features=64, out_features=64, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=64, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=64, out_features=64, bias=True)
#           (fc_gamma2): Linear(in_features=64, out_features=64, bias=True)
#           (bn_gamma1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=64, out_features=64, bias=True)
#         (fc2): Linear(in_features=64, out_features=64, bias=True)
#         (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): TransitionUpBlock(
#       (transition): TransitionUp(
#         (f1_fc): Linear(in_features=32, out_features=32, bias=True)
#         (f1_bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (f2_fc): Linear(in_features=64, out_features=32, bias=True)
#         (f2_bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (transformer): PointTransformerBlock(
#         (transformerLayer): PointTransformerLayer(
#           (query): Linear(in_features=32, out_features=32, bias=True)
#           (key): Linear(in_features=32, out_features=32, bias=True)
#           (value): Linear(in_features=32, out_features=32, bias=True)
#           (fc_delta1): Linear(in_features=3, out_features=3, bias=True)
#           (fc_delta2): Linear(in_features=3, out_features=32, bias=True)
#           (bn_delta): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (fc_gamma1): Linear(in_features=32, out_features=32, bias=True)
#           (fc_gamma2): Linear(in_features=32, out_features=32, bias=True)
#           (bn_gamma1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (bn_gamma2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (fc1): Linear(in_features=32, out_features=32, bias=True)
#         (fc2): Linear(in_features=32, out_features=32, bias=True)
#         (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn3): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (mlp3): SingleMLP(
#     (fc): Linear(in_features=32, out_features=5, bias=True)
#   )
# )

# %%
def normalize_points(points):
    points[:,:,:3] -= torch.mean(points[:,:,:3], dim=1)
    points[:,:,:3] /= torch.max(torch.abs(points[:,:,:3]), dim=1).values
    return points

def create_las(path:str, paris:Paris, model):
    # with torch.no_grad():
    points_list = []
    classes_list = []
    
    for i in range(paris.num_frames):
        points = paris.get_points(i)
        points_list.append(points)
        points = points.unsqueeze(0).cuda().type(torch.float32)
        points = normalize_points(points)
        
        with torch.no_grad():
            prediction = model(points)
            prediction = prediction.transpose(1, 2)
            prediction = torch.nn.functional.softmax(prediction, dim=1)
            prediction = prediction.argmax(dim=1).squeeze().detach().cpu()
            print(prediction.shape)
            print(prediction[prediction > 0])
            classes_list.append(prediction)
            
    points = torch.concatenate(points_list, dim=0).numpy()
    classes = torch.concatenate(classes_list, dim=0).numpy()
    intensity = points[:, 3] * 255
    intensity = intensity.astype(np.uint8)
    
    header = laspy.LasHeader(point_format=3, version="1.4")
    header.offsets = np.min(points[:,:3], axis=0)
    header.scales = np.array([0.01, 0.01, 0.01])
    # header.vlrs
    
    las = laspy.LasData(header)
    las.x = points[:,0]
    las.y = points[:,1]
    las.z = points[:,2]
    las.intensity = intensity
    las.classification = classes
    # las.gps_time = paris.gps_time
    # las.point_source_id = paris.frame_index
    
    las.write(path)
    print(f'{points.shape[0]} points were saved on {path}.')

# %%
create_las('./test.las', paris, seg_model)
# Out:
# torch.Size([49241])
# tensor([4, 4, 4,  ..., 4, 4, 4])
# torch.Size([49477])
# tensor([4, 4, 4,  ..., 1, 1, 1])
# torch.Size([49729])
# tensor([4, 4, 4,  ..., 1, 1, 1])
# torch.Size([49898])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([49922])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([49914])
# tensor([1, 1, 1,  ..., 4, 1, 4])
# torch.Size([49941])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([49003])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([49147])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([49539])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([49746])
# tensor([1, 1, 3,  ..., 1, 1, 1])
# torch.Size([49520])
# tensor([3, 3, 3,  ..., 1, 1, 1])
# torch.Size([49132])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48571])
# tensor([2, 3, 2,  ..., 4, 4, 4])
# torch.Size([48608])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48916])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([49269])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([49480])
# tensor([1, 3, 3,  ..., 4, 4, 4])
# torch.Size([49148])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48962])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48862])
# tensor([2, 2, 2,  ..., 4, 4, 4])
# torch.Size([48409])
# tensor([2, 3, 3,  ..., 4, 4, 4])
# torch.Size([48594])
# tensor([3, 2, 1,  ..., 4, 4, 4])
# torch.Size([47647])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([46603])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48003])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([49586])
# tensor([3, 3, 3,  ..., 4, 4, 1])
# torch.Size([50045])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([50133])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([50061])
# tensor([3, 3, 3,  ..., 4, 3, 3])
# torch.Size([50118])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([50044])
# tensor([3, 3, 3,  ..., 3, 3, 1])
# torch.Size([49948])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([49729])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([49407])
# tensor([1, 1, 3,  ..., 3, 3, 3])
# torch.Size([49413])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([49291])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([48874])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48661])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48438])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48507])
# tensor([1, 3, 3,  ..., 4, 4, 4])
# torch.Size([48312])
# tensor([4, 4, 4,  ..., 4, 4, 4])
# torch.Size([47915])
# tensor([1, 3, 3,  ..., 4, 4, 4])
# torch.Size([46794])
# tensor([3, 3, 3,  ..., 3, 4, 4])
# torch.Size([46787])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([47181])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([47468])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([47679])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([47930])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48094])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48340])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48712])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([48866])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48877])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48901])
# tensor([2, 2, 2,  ..., 4, 4, 4])
# torch.Size([48987])
# tensor([2, 2, 2,  ..., 4, 4, 4])
# torch.Size([48883])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48818])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48674])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([48390])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48132])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([47709])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([47504])
# tensor([2, 2, 2,  ..., 4, 4, 4])
# torch.Size([47267])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([47117])
# tensor([1, 1, 1,  ..., 3, 3, 4])
# torch.Size([46758])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([46260])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45884])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45369])
# tensor([1, 1, 1,  ..., 3, 3, 4])
# torch.Size([44113])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([43342])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([44239])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45249])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45364])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([45356])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45565])
# tensor([1, 1, 1,  ..., 3, 3, 4])
# torch.Size([44961])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([44596])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([44770])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45104])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45761])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([46251])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([46732])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([47276])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([47375])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([47276])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([46862])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([46464])
# tensor([4, 4, 4,  ..., 4, 3, 3])
# torch.Size([46084])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([46020])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45780])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45945])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([46119])
# tensor([1, 1, 3,  ..., 3, 3, 3])
# torch.Size([46303])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([46052])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([46150])
# tensor([3, 3, 3,  ..., 1, 1, 1])
# torch.Size([46396])
# tensor([3, 3, 3,  ..., 1, 1, 1])
# torch.Size([46593])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([46697])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([46769])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([46731])
# tensor([4, 4, 4,  ..., 4, 4, 4])
# torch.Size([46782])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([46265])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([45610])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([46087])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([47559])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48245])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48443])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48347])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48223])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48081])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48422])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48544])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48604])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([48408])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([47793])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([47212])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([46605])
# tensor([4, 4, 4,  ..., 4, 4, 4])
# torch.Size([46139])
# tensor([4, 4, 4,  ..., 4, 4, 4])
# torch.Size([45531])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([45077])
# tensor([2, 2, 2,  ..., 4, 4, 4])
# torch.Size([44974])
# tensor([1, 4, 1,  ..., 4, 4, 3])
# torch.Size([44708])
# tensor([1, 4, 4,  ..., 3, 3, 4])
# torch.Size([44100])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([43203])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([42482])
# tensor([1, 1, 4,  ..., 4, 4, 4])
# torch.Size([41735])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([41009])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([40469])
# tensor([2, 2, 2,  ..., 4, 4, 4])
# torch.Size([40157])
# tensor([2, 2, 2,  ..., 4, 4, 4])
# torch.Size([40088])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([40266])
# tensor([2, 2, 2,  ..., 1, 1, 1])
# torch.Size([40533])
# tensor([2, 2, 2,  ..., 1, 1, 1])
# torch.Size([40718])
# tensor([2, 2, 2,  ..., 1, 1, 1])
# torch.Size([40714])
# tensor([2, 2, 2,  ..., 1, 1, 1])
# torch.Size([40438])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([40281])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([40079])
# tensor([1, 1, 1,  ..., 1, 1, 1])
# torch.Size([39804])
# tensor([3, 3, 3,  ..., 1, 1, 1])
# torch.Size([39790])
# tensor([3, 2, 3,  ..., 1, 1, 1])
# torch.Size([39950])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([40419])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([40946])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([41502])
# tensor([4, 4, 4,  ..., 1, 1, 1])
# torch.Size([41984])
# tensor([4, 4, 4,  ..., 1, 1, 1])
# torch.Size([42376])
# tensor([4, 4, 4,  ..., 1, 1, 1])
# torch.Size([42690])
# tensor([4, 4, 4,  ..., 1, 1, 1])
# torch.Size([43064])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([43369])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([43524])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([43804])
# tensor([1, 2, 2,  ..., 4, 4, 4])
# torch.Size([44025])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([44250])
# tensor([2, 3, 2,  ..., 3, 1, 1])
# torch.Size([44554])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([44857])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([45195])
# tensor([1, 1, 3,  ..., 3, 3, 3])
# torch.Size([45417])
# tensor([4, 4, 4,  ..., 1, 3, 3])
# torch.Size([45601])
# tensor([4, 4, 4,  ..., 3, 1, 1])
# torch.Size([45600])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([45424])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([44953])
# tensor([2, 3, 3,  ..., 3, 3, 3])
# torch.Size([44568])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([43984])
# tensor([1, 1, 2,  ..., 3, 3, 3])
# torch.Size([43691])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([43484])
# tensor([2, 2, 2,  ..., 1, 1, 1])
# torch.Size([43326])
# tensor([3, 3, 3,  ..., 4, 4, 4])
# torch.Size([42922])
# tensor([2, 2, 3,  ..., 4, 4, 4])
# torch.Size([42493])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([42038])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([41683])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([41432])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([41185])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([41130])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([41269])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([41454])
# tensor([2, 3, 3,  ..., 3, 3, 3])
# torch.Size([41780])
# tensor([2, 2, 2,  ..., 4, 4, 3])
# torch.Size([42085])
# tensor([2, 2, 2,  ..., 4, 4, 3])
# torch.Size([42300])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([42900])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([43589])
# tensor([1, 1, 1,  ..., 4, 4, 4])
# torch.Size([44471])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([45285])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([45752])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([46471])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([47007])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([47468])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([47525])
# tensor([3, 3, 3,  ..., 3, 3, 3])
# torch.Size([47669])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48003])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48233])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48801])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([49230])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([49609])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([49442])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([49382])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([49299])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48965])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48902])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48869])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48582])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48313])
# tensor([1, 1, 1,  ..., 3, 3, 1])
# torch.Size([48288])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48344])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48253])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48091])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48109])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48350])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([48215])
# tensor([4, 4, 4,  ..., 3, 3, 3])
# torch.Size([48043])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48170])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# torch.Size([48302])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48607])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48612])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48477])
# tensor([1, 1, 1,  ..., 3, 3, 3])
# torch.Size([48256])
# tensor([2, 2, 2,  ..., 3, 3, 3])
# 9959176 points were saved on ./test.las.
